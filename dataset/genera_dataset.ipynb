# %% [markdown]
# # Controllo dataset e duplicati nei titoli

# %%
import pandas as pd
import os
from pathlib import Path

# %% [markdown]
# ## Caricamento del CSV in un DataFrame

# %%
df = pd.read_csv('./a.csv')
print(df.shape)
print(df.info())
# Out:
# (34886, 8)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34886 entries, 0 to 34885
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Release Year      34886 non-null  int64
#  1   Title             34886 non-null  object
#  2   Origin/Ethnicity  34886 non-null  object
#  3   Director          34886 non-null  object
#  4   Cast              33464 non-null  object
#  5   Genre             34886 non-null  object
#  6   Wiki Page         34886 non-null  object
#  7   Plot              34886 non-null  object
# dtypes: int64(1), object(7)
# memory usage: 2.1+ MB
# None

# %%
df.head(5)
# Out:
#    Release Year                             Title Origin/Ethnicity  \
# 0          1901            Kansas Saloon Smashers         American
# 1          1901     Love by the Light of the Moon         American
# 2          1901           The Martyred Presidents         American
# 3          1901  Terrible Teddy, the Grizzly King         American
# 4          1902            Jack and the Beanstalk         American
#
#                              Director Cast    Genre  \
# 0                             Unknown  NaN  unknown
# 1                             Unknown  NaN  unknown
# 2                             Unknown  NaN  unknown
# 3                             Unknown  NaN  unknown
# 4  George S. Fleming, Edwin S. Porter  NaN  unknown
#
#                                            Wiki Page  \
# 0  https://en.wikipedia.org/wiki/Kansas_Saloon_Sm...
# 1  https://en.wikipedia.org/wiki/Love_by_the_Ligh...
# 2  https://en.wikipedia.org/wiki/The_Martyred_Pre...
# 3  https://en.wikipedia.org/wiki/Terrible_Teddy,_...
# 4  https://en.wikipedia.org/wiki/Jack_and_the_Bea...
#
#                                                 Plot
# 0  A bartender is working at a saloon, serving dr...
# 1  The moon, painted with a smiling face hangs ov...
# 2  The film, just over a minute long, is composed...
# 3  Lasting just 61 seconds and consisting of two ...
# 4  The earliest known adaptation of the classic f...

# %% [markdown]
# ## Analisi dettagliata dei titoli duplicati
# Analizziamo in modo più chiaro i duplicati:
# 1. Troviamo se esistono duplicati
# 2. Creiamo una lista dei titoli duplicati
# 3. Mostriamo quante volte appare ciascun titolo duplicato

# %%
# Troviamo i titoli duplicati
# value_counts() conta quante volte appare ogni titolo
conteggio_titoli = df['Title'].value_counts()

# Filtriamo solo i titoli che appaiono più di una volta
titoli_duplicati = conteggio_titoli[conteggio_titoli > 1]

if len(titoli_duplicati) > 0:
    print(f"Trovati {len(titoli_duplicati)} titoli duplicati\n")
    print("Lista dei titoli duplicati e numero di occorrenze:")
    print("="*50)
    
    # Creiamo una lista ordinata dei titoli duplicati con il loro conteggio
    for titolo, conteggio in titoli_duplicati.items():
        print(f"'{titolo}': {conteggio} occorrenze")
    
    # Creiamo una lista dei soli titoli duplicati
    lista_titoli_duplicati = list(titoli_duplicati.index)
    
    print("\nLista dei titoli duplicati:")
    print("="*50)
    for i, titolo in enumerate(lista_titoli_duplicati, 1):
        print(f"{i}. {titolo}")
else:
    print("Non sono stati trovati titoli duplicati nel dataset")
# Out:
# Trovati 2071 titoli duplicati
#
# Lista dei titoli duplicati e numero di occorrenze:
# ==================================================
# 'The Three Musketeers': 8 occorrenze
# 'Cinderella': 8 occorrenze
# 'Treasure Island': 7 occorrenze
# 'Anna Karenina': 6 occorrenze
# 'Alice in Wonderland': 6 occorrenze
# 'Hero': 6 occorrenze
# 'Mother': 5 occorrenze
# 'I Love You': 5 occorrenze
# 'Criminal': 5 occorrenze
# 'Madame X': 5 occorrenze
# 'Angel': 5 occorrenze
# 'Dr. Jekyll and Mr. Hyde': 5 occorrenze
# 'Dushman': 5 occorrenze
# 'Love': 5 occorrenze
# 'Cleopatra': 5 occorrenze
# 'Kidnapped': 5 occorrenze
# 'Robin Hood': 5 occorrenze
# 'Brewster's Millions': 5 occorrenze
# 'Love Story': 4 occorrenze
# 'Dracula': 4 occorrenze
# 'Dressed to Kill': 4 occorrenze
# 'Night Watch': 4 occorrenze
# '23': 4 occorrenze
# 'Bad Company': 4 occorrenze
# 'Hide and Seek': 4 occorrenze
# 'Jigsaw': 4 occorrenze
# 'Branded': 4 occorrenze
# 'Romance': 4 occorrenze
# 'Shikari': 4 occorrenze
# 'Duniya': 4 occorrenze
# 'Trapped': 4 occorrenze
# 'The Bodyguard': 4 occorrenze
# 'Joker': 4 occorrenze
# 'Chandralekha': 4 occorrenze
# 'The Crossing': 4 occorrenze
# 'Julie': 4 occorrenze
# 'The Jazz Singer': 4 occorrenze
# 'Carrie': 4 occorrenze
# 'No Escape': 4 occorrenze
# 'C.I.D.': 4 occorrenze
# 'The Adventurers': 4 occorrenze
# 'Hamlet': 4 occorrenze
# 'Possessed': 4 occorrenze
# 'The Hole': 4 occorrenze
# 'Sahara': 4 occorrenze
# 'Blind Date': 4 occorrenze
# 'Darling': 4 occorrenze
# 'Guru': 4 occorrenze
# 'Rage': 4 occorrenze
# '9': 4 occorrenze
# 'Bodyguard': 4 occorrenze
# 'Wanted': 4 occorrenze
# 'Forbidden': 4 occorrenze
# 'Abhimanyu': 4 occorrenze
# 'Running Scared': 4 occorrenze
# 'The Raven': 4 occorrenze
# 'Rajkumar': 4 occorrenze
# '21': 4 occorrenze
# 'Chakravarthy': 4 occorrenze
# 'Oliver Twist': 4 occorrenze
# 'Heat': 4 occorrenze
# 'A Christmas Carol': 4 occorrenze
# 'The Prisoner of Zenda': 4 occorrenze
# 'The Outsider': 4 occorrenze
# 'The Chase': 4 occorrenze
# 'Kismet': 4 occorrenze
# 'Honeymoon': 4 occorrenze
# 'Rocky': 4 occorrenze
# 'Black and White': 4 occorrenze
# 'The Mummy': 4 occorrenze
# 'Cocktail': 4 occorrenze
# 'Far from the Madding Crowd': 3 occorrenze
# 'Beautiful': 3 occorrenze
# 'Shakedown': 3 occorrenze
# 'Iron Man': 3 occorrenze
# 'To Die For': 3 occorrenze
# 'Don't Be Afraid of the Dark': 3 occorrenze
# 'Raw Deal': 3 occorrenze
# 'Fury': 3 occorrenze
# 'Fever Pitch': 3 occorrenze
# 'Jayam': 3 occorrenze
# 'Brahmachari': 3 occorrenze
# 'Caravan': 3 occorrenze
# 'Fortress': 3 occorrenze
# 'Piranha': 3 occorrenze
# 'Maindhan': 3 occorrenze
# '24': 3 occorrenze
# 'The Hunted': 3 occorrenze
# 'Power': 3 occorrenze
# 'Book of Love': 3 occorrenze
# 'Khandan': 3 occorrenze
# 'Titanic': 3 occorrenze
# 'Crossed Swords': 3 occorrenze
# 'Chandirani': 3 occorrenze
# 'Anarkali': 3 occorrenze
# 'Next of Kin': 3 occorrenze
# 'The Spoilers': 3 occorrenze
# 'Ishtam': 3 occorrenze
# 'Aurat': 3 occorrenze
# 'Jane Eyre': 3 occorrenze
# 'Hercules': 3 occorrenze
# 'The Hunchback of Notre Dame': 3 occorrenze
# 'Chori Chori': 3 occorrenze
# 'Kangaroo': 3 occorrenze
# 'Prometheus': 3 occorrenze
# 'The Cat and the Canary': 3 occorrenze
# 'Housefull': 3 occorrenze
# 'The Promise': 3 occorrenze
# 'Murder on the Orient Express': 3 occorrenze
# 'Holiday': 3 occorrenze
# 'Casino Royale': 3 occorrenze
# 'Yashoda Krishna': 3 occorrenze
# 'The Star': 3 occorrenze
# 'Mysterious Island': 3 occorrenze
# 'The Age of Innocence': 3 occorrenze
# 'Zindagi': 3 occorrenze
# 'Special Delivery': 3 occorrenze
# 'Revenge': 3 occorrenze
# 'Black Beauty': 3 occorrenze
# 'Gentleman': 3 occorrenze
# 'Brothers': 3 occorrenze
# 'Suraj': 3 occorrenze
# 'Classmates': 3 occorrenze
# 'The Suspect': 3 occorrenze
# 'Anne of Green Gables': 3 occorrenze
# 'Legend': 3 occorrenze
# 'Once Upon a Time': 3 occorrenze
# '4': 3 occorrenze
# 'Hulchul': 3 occorrenze
# 'Solo': 3 occorrenze
# 'Blackmail': 3 occorrenze
# 'My Cousin Rachel': 3 occorrenze
# 'Captain America': 3 occorrenze
# 'Escape': 3 occorrenze
# 'Triangle': 3 occorrenze
# 'Heartbeat': 3 occorrenze
# 'Mayabazar': 3 occorrenze
# 'Reckless': 3 occorrenze
# 'Of Human Bondage': 3 occorrenze
# 'The Journey': 3 occorrenze
# 'Alexander': 3 occorrenze
# 'Arizona': 3 occorrenze
# 'Deadfall': 3 occorrenze
# 'ATM': 3 occorrenze
# 'The Rookie': 3 occorrenze
# 'Ajantha': 3 occorrenze
# 'About Love': 3 occorrenze
# 'Black Widow': 3 occorrenze
# 'The Unseen': 3 occorrenze
# 'Kismat': 3 occorrenze
# 'The Eagle': 3 occorrenze
# 'Aag': 3 occorrenze
# 'Tormented': 3 occorrenze
# 'Touch and Go': 3 occorrenze
# 'The Crimson Circle': 3 occorrenze
# 'Devdas': 3 occorrenze
# 'Accident': 3 occorrenze
# 'Godzilla': 3 occorrenze
# 'Andaz': 3 occorrenze
# 'Manzil': 3 occorrenze
# '12': 3 occorrenze
# 'Om': 3 occorrenze
# 'Lost and Found': 3 occorrenze
# 'Inside Out': 3 occorrenze
# '14': 3 occorrenze
# '16': 3 occorrenze
# 'Hindle Wakes': 3 occorrenze
# 'Aankhen': 3 occorrenze
# 'Jaal': 3 occorrenze
# 'Sunny': 3 occorrenze
# 'Seven Sinners': 3 occorrenze
# 'The Fake': 3 occorrenze
# 'Hitman': 3 occorrenze
# '123': 3 occorrenze
# 'Neighbors': 3 occorrenze
# 'She': 3 occorrenze
# 'Neel Kamal': 3 occorrenze
# 'Framed': 3 occorrenze
# 'Cake': 3 occorrenze
# 'The Last of the Mohicans': 3 occorrenze
# 'Gemini': 3 occorrenze
# 'Annie': 3 occorrenze
# 'Gambit': 3 occorrenze
# 'Black Magic': 3 occorrenze
# 'Waterfront': 3 occorrenze
# 'The Witness': 3 occorrenze
# 'Fast and Loose': 3 occorrenze
# 'Peter Pan': 3 occorrenze
# 'A Shot in the Dark': 3 occorrenze
# 'Aadmi': 3 occorrenze
# 'Contraband': 3 occorrenze
# 'Musafir': 3 occorrenze
# 'The Brothers': 3 occorrenze
# 'Victory': 3 occorrenze
# 'Race': 3 occorrenze
# 'Blood': 3 occorrenze
# 'Anari': 3 occorrenze
# 'Kanchana': 3 occorrenze
# 'Rampage': 3 occorrenze
# 'Lion': 3 occorrenze
# 'The Other Side of the Door': 3 occorrenze
# 'Sherlock Holmes': 3 occorrenze
# 'Mausam': 3 occorrenze
# 'April Fool': 3 occorrenze
# 'Victim': 3 occorrenze
# 'Run': 3 occorrenze
# 'The Squaw Man': 3 occorrenze
# 'Underworld': 3 occorrenze
# 'Rush': 3 occorrenze
# 'The Terror': 3 occorrenze
# 'Orange': 3 occorrenze
# 'Taxi Driver': 3 occorrenze
# 'Batman': 3 occorrenze
# 'Obsessed': 3 occorrenze
# 'King Kong': 3 occorrenze
# 'Pizza': 3 occorrenze
# 'The Battle of the Sexes': 3 occorrenze
# 'Hitler': 3 occorrenze
# 'Back Street': 3 occorrenze
# '20,000 Leagues Under the Sea': 3 occorrenze
# 'Edge of Darkness': 3 occorrenze
# 'The Patriot': 3 occorrenze
# 'Fast Company': 3 occorrenze
# 'Crossroads': 3 occorrenze
# 'Mob Story': 3 occorrenze
# 'King Solomon's Mines': 3 occorrenze
# 'That's My Boy': 3 occorrenze
# 'Payback': 3 occorrenze
# 'Manithan': 3 occorrenze
# 'Adalat': 3 occorrenze
# 'Backlash': 3 occorrenze
# 'Chanti': 3 occorrenze
# 'Frozen': 3 occorrenze
# 'Flight': 3 occorrenze
# 'Paradise': 3 occorrenze
# 'Aakrosh': 3 occorrenze
# 'Miracle on 34th Street': 3 occorrenze
# 'Quartet': 3 occorrenze
# 'Beauty and the Beast': 3 occorrenze
# 'Mappillai': 3 occorrenze
# 'Just My Luck': 3 occorrenze
# 'Chitram Bhalare Vichitram': 3 occorrenze
# 'Sangram': 3 occorrenze
# 'Charade': 3 occorrenze
# 'Show Boat': 3 occorrenze
# 'Metro': 3 occorrenze
# 'Billa': 3 occorrenze
# 'It': 3 occorrenze
# 'Ghost': 3 occorrenze
# 'Laila Majnu': 3 occorrenze
# 'For Love or Money': 3 occorrenze
# 'Great Expectations': 3 occorrenze
# 'Surrender': 3 occorrenze
# 'Villain': 3 occorrenze
# 'Abhinetri': 3 occorrenze
# 'Catacombs': 3 occorrenze
# 'Inferno': 3 occorrenze
# 'The Road': 3 occorrenze
# 'Once a Thief': 3 occorrenze
# 'Betrayal': 3 occorrenze
# 'The Trap': 3 occorrenze
# 'Krishna': 3 occorrenze
# 'Confession': 3 occorrenze
# 'Macbeth': 3 occorrenze
# 'Camille': 3 occorrenze
# 'The Heartbreak Kid': 3 occorrenze
# 'Meera': 3 occorrenze
# 'Runaway': 3 occorrenze
# 'Unfinished Business': 3 occorrenze
# 'The Call of the Wild': 3 occorrenze
# 'Mangalyam': 3 occorrenze
# 'Ramu': 3 occorrenze
# 'Little Women': 3 occorrenze
# 'Love Affair': 3 occorrenze
# 'The Other Woman': 3 occorrenze
# 'Thru the Moebius Strip': 3 occorrenze
# 'School Master': 3 occorrenze
# 'Scrooge': 3 occorrenze
# 'Bandhan': 3 occorrenze
# 'Takkar': 3 occorrenze
# 'Angela': 3 occorrenze
# 'Nightmare': 3 occorrenze
# 'Shikar': 3 occorrenze
# 'The Thin Red Line': 2 occorrenze
# 'Multi-Facial': 2 occorrenze
# 'Shivalinga': 2 occorrenze
# 'Sangam': 2 occorrenze
# 'Kotigobba 2': 2 occorrenze
# 'Madurai Veeran': 2 occorrenze
# 'Mutiny on the Bounty': 2 occorrenze
# 'The Double': 2 occorrenze
# 'Saathi': 2 occorrenze
# 'Made in Heaven': 2 occorrenze
# 'Aradhana': 2 occorrenze
# 'The Long Ships': 2 occorrenze
# 'The Walking Dead': 2 occorrenze
# 'Raam': 2 occorrenze
# 'Shock Treatment': 2 occorrenze
# 'Hanna': 2 occorrenze
# 'Kind Lady': 2 occorrenze
# 'Killer Elite': 2 occorrenze
# 'English: An Autumn in London': 2 occorrenze
# 'Jadoo': 2 occorrenze
# 'Lucky': 2 occorrenze
# 'On the Black Hill': 2 occorrenze
# 'Out of Bounds': 2 occorrenze
# 'Brainstorm': 2 occorrenze
# 'The Great Impersonation': 2 occorrenze
# 'Death at a Funeral': 2 occorrenze
# 'Ripley's Game': 2 occorrenze
# 'Arasu': 2 occorrenze
# 'Dark Blue': 2 occorrenze
# 'Dharti': 2 occorrenze
# 'The Glass Key': 2 occorrenze
# 'Geet': 2 occorrenze
# 'Tiger': 2 occorrenze
# 'Flipper': 2 occorrenze
# 'One Day': 2 occorrenze
# 'Nobody's Fool': 2 occorrenze
# 'Ghar Ghar Ki Kahani': 2 occorrenze
# 'Paul': 2 occorrenze
# 'Nil Gavani Sellathey': 2 occorrenze
# 'No Mercy': 2 occorrenze
# 'Broken': 2 occorrenze
# 'The Collector': 2 occorrenze
# 'Ittefaq': 2 occorrenze
# 'Meatballs III: Summer Job': 2 occorrenze
# 'A Midsummer Night's Dream': 2 occorrenze
# 'Mulzim': 2 occorrenze
# 'Going the Distance': 2 occorrenze
# 'Zamindar': 2 occorrenze
# 'The Train': 2 occorrenze
# 'The Visit': 2 occorrenze
# 'Poolhall Junkies': 2 occorrenze
# 'Saving Grace': 2 occorrenze
# 'Mr. Nice Guy': 2 occorrenze
# 'Magnificent Obsession': 2 occorrenze
# 'Bahurani': 2 occorrenze
# 'Jump': 2 occorrenze
# 'Robotech: The Movie': 2 occorrenze
# 'Big City': 2 occorrenze
# 'No Man's Land': 2 occorrenze
# 'The Haunting': 2 occorrenze
# 'Dirty Girl': 2 occorrenze
# 'The Young Lovers': 2 occorrenze
# 'Little Big Shot': 2 occorrenze
# '36 Hours': 2 occorrenze
# 'Still Life': 2 occorrenze
# 'The Last Outpost': 2 occorrenze
# 'Birthday Girl': 2 occorrenze
# 'Shatranj': 2 occorrenze
# 'Mad Love': 2 occorrenze
# 'Godfather': 2 occorrenze
# 'Kalvanin Kadhali': 2 occorrenze
# 'Cross My Heart': 2 occorrenze
# 'Happy New Year': 2 occorrenze
# 'Firelight': 2 occorrenze
# 'First Men in the Moon': 2 occorrenze
# 'The Charge of the Light Brigade': 2 occorrenze
# 'Proof of the Man': 2 occorrenze
# 'Scared Stiff': 2 occorrenze
# 'Upkar': 2 occorrenze
# 'A Better Tomorrow': 2 occorrenze
# 'Ram Aur Shyam': 2 occorrenze
# 'Pudhumai Pithan': 2 occorrenze
# 'Andha Naal': 2 occorrenze
# 'Farz': 2 occorrenze
# 'Hamraaz': 2 occorrenze
# 'The Milky Way': 2 occorrenze
# 'The Big Show': 2 occorrenze
# 'Shagird': 2 occorrenze
# 'Hot Pursuit': 2 occorrenze
# 'Jewel Thief': 2 occorrenze
# 'Transylvania 6-5000': 2 occorrenze
# 'Milan': 2 occorrenze
# 'Metro Manila': 2 occorrenze
# 'Gunmen': 2 occorrenze
# 'The Raid': 2 occorrenze
# 'Whistle': 2 occorrenze
# 'Resident Evil: Afterlife': 2 occorrenze
# 'Chandra': 2 occorrenze
# 'Red': 2 occorrenze
# 'Viduthalai': 2 occorrenze
# 'Teesri Manzil': 2 occorrenze
# 'Crack in the World': 2 occorrenze
# 'The Best Man': 2 occorrenze
# 'Yogi': 2 occorrenze
# 'Aaye Din Bahar Ke': 2 occorrenze
# 'Goa': 2 occorrenze
# 'Dolls': 2 occorrenze
# 'Deadline': 2 occorrenze
# 'Hollywood Boulevard': 2 occorrenze
# 'Simple Agi Ondh Love Story': 2 occorrenze
# 'Highway': 2 occorrenze
# 'House of Secrets': 2 occorrenze
# 'Jaganmohini': 2 occorrenze
# 'Stone': 2 occorrenze
# 'Desire': 2 occorrenze
# 'The Switch': 2 occorrenze
# 'Pirates of the Caribbean: On Stranger Tides': 2 occorrenze
# 'The Gate': 2 occorrenze
# 'Crack-Up': 2 occorrenze
# 'Naattiya Thara': 2 occorrenze
# 'Conflict': 2 occorrenze
# 'Police Story': 2 occorrenze
# 'Masterpiece': 2 occorrenze
# 'McHale's Navy': 2 occorrenze
# 'Riffraff': 2 occorrenze
# 'Do Kaliyaan': 2 occorrenze
# 'Showdown': 2 occorrenze
# 'Kanyadaan': 2 occorrenze
# 'Killers': 2 occorrenze
# 'Doraemon: Nobita and the Haunts of Evil': 2 occorrenze
# 'Mythri': 2 occorrenze
# 'Small Town Girl': 2 occorrenze
# 'Haseena Maan Jayegi': 2 occorrenze
# 'Assassination': 2 occorrenze
# 'My Man Godfrey': 2 occorrenze
# 'Kashmir Ki Kali': 2 occorrenze
# 'Ziddi': 2 occorrenze
# 'Aulad': 2 occorrenze
# 'Lionheart': 2 occorrenze
# 'The Plan': 2 occorrenze
# 'The Texas Rangers': 2 occorrenze
# 'Jackie': 2 occorrenze
# 'Shourya': 2 occorrenze
# 'Dosti': 2 occorrenze
# 'Red Salute': 2 occorrenze
# 'Ayee Milan Ki Bela': 2 occorrenze
# 'The Nutty Professor': 2 occorrenze
# 'Monsoon Shootout': 2 occorrenze
# 'The Pink Panther': 2 occorrenze
# 'Howling III': 2 occorrenze
# 'Ghost Ship': 2 occorrenze
# 'Aamne Samne': 2 occorrenze
# 'Pennies from Heaven': 2 occorrenze
# 'Loophole': 2 occorrenze
# 'The Four Feathers': 2 occorrenze
# 'The Woman in Red': 2 occorrenze
# 'Robinson Crusoe': 2 occorrenze
# 'Dhool': 2 occorrenze
# 'Floods of Fear': 2 occorrenze
# 'Dunkirk': 2 occorrenze
# 'Leader': 2 occorrenze
# 'Reunion': 2 occorrenze
# 'Lassie': 2 occorrenze
# 'The Plainsman': 2 occorrenze
# 'Emperor Tomato Ketchup': 2 occorrenze
# 'Welcome Home': 2 occorrenze
# 'Gunahon Ka Devta': 2 occorrenze
# 'A Better Tomorrow 2': 2 occorrenze
# 'Rana Vikrama': 2 occorrenze
# 'Love Letters': 2 occorrenze
# 'Sabrina': 2 occorrenze
# 'Arthur Christmas': 2 occorrenze
# 'Looking for Love': 2 occorrenze
# 'A Tale of Two Cities': 2 occorrenze
# 'Raaz': 2 occorrenze
# 'Spellbound': 2 occorrenze
# 'Aftershock': 2 occorrenze
# 'The Browning Version': 2 occorrenze
# 'Special Correspondents': 2 occorrenze
# 'Bridge to Terabithia': 2 occorrenze
# 'King Kong Escapes': 2 occorrenze
# '12 Years a Slave': 2 occorrenze
# 'The Verdict': 2 occorrenze
# 'Speechless': 2 occorrenze
# 'Kedi': 2 occorrenze
# 'Amar Akbar Anthony': 2 occorrenze
# 'In Cold Blood': 2 occorrenze
# 'Commando': 2 occorrenze
# 'Aap Ki Khatir': 2 occorrenze
# 'Hotel': 2 occorrenze
# 'Luxury Liner': 2 occorrenze
# 'The Vow': 2 occorrenze
# 'Cyborg She': 2 occorrenze
# 'Boomerang': 2 occorrenze
# 'The Eagle and the Hawk': 2 occorrenze
# 'Priyatama': 2 occorrenze
# 'Blind Spot': 2 occorrenze
# 'Up the Creek': 2 occorrenze
# 'Bartleby': 2 occorrenze
# 'The Black Widow': 2 occorrenze
# 'The Wild Life': 2 occorrenze
# 'The Yearling': 2 occorrenze
# 'Lingaa': 2 occorrenze
# 'Forgotten': 2 occorrenze
# 'Flirt': 2 occorrenze
# 'Beware of Pickpockets': 2 occorrenze
# 'Goodbye Again': 2 occorrenze
# 'Grand Slam': 2 occorrenze
# 'Rangoon': 2 occorrenze
# 'Fair Game': 2 occorrenze
# 'The Big Fix': 2 occorrenze
# 'Daddy': 2 occorrenze
# 'Bale Pandiya': 2 occorrenze
# 'Eye in the Sky': 2 occorrenze
# 'The Reluctant Fundamentalist': 2 occorrenze
# 'The Importance of Being Earnest': 2 occorrenze
# 'Death Note 2: The Last Name': 2 occorrenze
# 'Sanyasi': 2 occorrenze
# 'Mama Loves Papa': 2 occorrenze
# 'Salaakhen': 2 occorrenze
# 'Prem Kahani': 2 occorrenze
# 'Muni': 2 occorrenze
# 'The Spiral Staircase': 2 occorrenze
# 'Mili': 2 occorrenze
# 'Return to Paradise': 2 occorrenze
# 'Mad Max Beyond Thunderdome': 2 occorrenze
# 'The Master': 2 occorrenze
# 'Catherine the Great': 2 occorrenze
# 'Creature': 2 occorrenze
# 'The Unspeakable Act': 2 occorrenze
# 'Aaina': 2 occorrenze
# 'The Duel': 2 occorrenze
# 'Morning Glory': 2 occorrenze
# 'The Happening': 2 occorrenze
# 'Don't Say a Word': 2 occorrenze
# 'Night Flight': 2 occorrenze
# 'Chalte Chalte': 2 occorrenze
# 'Hera Pheri': 2 occorrenze
# 'Only Yesterday': 2 occorrenze
# 'Final Justice': 2 occorrenze
# 'Never Let Me Go': 2 occorrenze
# 'Room': 2 occorrenze
# 'Sinister': 2 occorrenze
# 'Fright Night': 2 occorrenze
# 'Cry, the Beloved Country': 2 occorrenze
# 'Lady Whirlwind': 2 occorrenze
# 'Anbe Vaa': 2 occorrenze
# 'Heartbreakers': 2 occorrenze
# 'Scarface': 2 occorrenze
# 'Unnaipol Oruvan': 2 occorrenze
# 'Iceman': 2 occorrenze
# 'The Fugitive': 2 occorrenze
# 'The Karate Kid': 2 occorrenze
# 'Born to Kill': 2 occorrenze
# 'Surakshaa': 2 occorrenze
# 'The Party': 2 occorrenze
# 'Yaariyan': 2 occorrenze
# 'Pazhani': 2 occorrenze
# 'The Foreigner': 2 occorrenze
# 'The Winslow Boy': 2 occorrenze
# 'Gravity': 2 occorrenze
# 'The Girl Next Door': 2 occorrenze
# 'Planet of the Apes': 2 occorrenze
# 'Kick-Ass 2': 2 occorrenze
# 'Murders in the Rue Morgue': 2 occorrenze
# 'Man of the House': 2 occorrenze
# 'The Thomas Crown Affair': 2 occorrenze
# 'No Man of Her Own': 2 occorrenze
# 'Finders Keepers': 2 occorrenze
# 'Sweet November': 2 occorrenze
# 'Inside Llewyn Davis': 2 occorrenze
# 'Miranda': 2 occorrenze
# 'Partners': 2 occorrenze
# 'Flashpoint': 2 occorrenze
# 'Footloose': 2 occorrenze
# 'Major Chandrakanth': 2 occorrenze
# 'Judaai': 2 occorrenze
# 'Ghostbusters': 2 occorrenze
# 'Boss': 2 occorrenze
# 'Dostana': 2 occorrenze
# 'Pack Up Your Troubles': 2 occorrenze
# 'Into the White Night': 2 occorrenze
# 'Khatta Meetha': 2 occorrenze
# 'The Queen of Spades': 2 occorrenze
# 'Concussion': 2 occorrenze
# 'Kick': 2 occorrenze
# 'Sheena': 2 occorrenze
# 'Countdown': 2 occorrenze
# 'Candy': 2 occorrenze
# 'Night of the Living Dead': 2 occorrenze
# 'Whisky Galore!': 2 occorrenze
# 'Calendar Girl': 2 occorrenze
# 'Corruption': 2 occorrenze
# 'The Body Said No!': 2 occorrenze
# 'Let's Do It Again': 2 occorrenze
# 'Zamaanat': 2 occorrenze
# 'Swami': 2 occorrenze
# 'Gone to Earth': 2 occorrenze
# 'Don': 2 occorrenze
# 'More Dead Than Alive': 2 occorrenze
# 'Traffic': 2 occorrenze
# 'Down to Earth': 2 occorrenze
# 'Lahu Ke Do Rang': 2 occorrenze
# 'Jurmana': 2 occorrenze
# 'A Nightmare on Elm Street': 2 occorrenze
# 'Vanity Fair': 2 occorrenze
# 'Helter Skelter': 2 occorrenze
# 'Jennifer': 2 occorrenze
# 'Escape from Planet Earth': 2 occorrenze
# 'Winner Take All': 2 occorrenze
# 'House of Wax': 2 occorrenze
# 'I, the Jury': 2 occorrenze
# 'Kochadaiiyaan': 2 occorrenze
# 'Invaders from Mars': 2 occorrenze
# 'Red Dawn': 2 occorrenze
# 'Navarathri': 2 occorrenze
# 'Vettaikkaran': 2 occorrenze
# 'What Every Woman Wants': 2 occorrenze
# 'Fire with Fire': 2 occorrenze
# 'There's Always Tomorrow': 2 occorrenze
# 'The Bounty Hunter': 2 occorrenze
# 'Sylvia': 2 occorrenze
# 'Strange Bedfellows': 2 occorrenze
# 'Deception': 2 occorrenze
# 'Mischief': 2 occorrenze
# 'Hare Rama Hare Krishna': 2 occorrenze
# 'Sarangadhara': 2 occorrenze
# 'ABCs of Death, TheThe ABCs of Death': 2 occorrenze
# 'Whirlpool': 2 occorrenze
# 'Elaan': 2 occorrenze
# 'Woman in the Dark': 2 occorrenze
# 'Sri Manjunatha': 2 occorrenze
# 'Henry: Portrait of a Serial Killer': 2 occorrenze
# 'Uthama Puthiran': 2 occorrenze
# 'Nala Damayanthi': 2 occorrenze
# 'Black Rock': 2 occorrenze
# 'Big Miracle': 2 occorrenze
# 'Beyond': 2 occorrenze
# 'Nishkarsha': 2 occorrenze
# 'Best Man Down': 2 occorrenze
# 'Chef': 2 occorrenze
# 'Bait': 2 occorrenze
# 'Tere Mere Sapne': 2 occorrenze
# 'Kotreshi Kanasu': 2 occorrenze
# 'Crawlspace': 2 occorrenze
# 'The Scarlet Letter': 2 occorrenze
# 'Betrayed': 2 occorrenze
# 'The Show-Off': 2 occorrenze
# 'Fear': 2 occorrenze
# 'Tezz': 2 occorrenze
# 'Thozha': 2 occorrenze
# 'Bombay to Goa': 2 occorrenze
# 'Super': 2 occorrenze
# 'Ayya': 2 occorrenze
# 'Miracles': 2 occorrenze
# 'Dragnet': 2 occorrenze
# 'A High Wind in Jamaica': 2 occorrenze
# 'About a Boy': 2 occorrenze
# 'Harlow': 2 occorrenze
# 'The Reunion': 2 occorrenze
# '36 Deadly Styles': 2 occorrenze
# 'The Big Sleep': 2 occorrenze
# 'Enchanted April': 2 occorrenze
# 'Escapade': 2 occorrenze
# 'My Little Girl': 2 occorrenze
# 'Fighting Youth': 2 occorrenze
# 'My Little Pony: The Movie': 2 occorrenze
# 'Freckles': 2 occorrenze
# 'Priest': 2 occorrenze
# 'Restless': 2 occorrenze
# 'The Hitcher': 2 occorrenze
# 'X-Men: First Class': 2 occorrenze
# 'Nagarahavu': 2 occorrenze
# 'Never Too Late': 2 occorrenze
# 'House': 2 occorrenze
# 'The Way': 2 occorrenze
# 'Nadodi Mannan': 2 occorrenze
# 'Warrior': 2 occorrenze
# 'The Secret': 2 occorrenze
# 'Unknown': 2 occorrenze
# 'Black Sheep': 2 occorrenze
# 'Anubhav': 2 occorrenze
# 'Bordertown': 2 occorrenze
# 'Born to Gamble': 2 occorrenze
# 'Richard III': 2 occorrenze
# 'Anand': 2 occorrenze
# 'Mister Moses': 2 occorrenze
# 'The Jungle Book': 2 occorrenze
# 'The Shooting': 2 occorrenze
# 'Notorious': 2 occorrenze
# 'Bang': 2 occorrenze
# 'The Count of Monte Cristo': 2 occorrenze
# 'Intimate Relations': 2 occorrenze
# 'Gone': 2 occorrenze
# 'Never Say Goodbye': 2 occorrenze
# 'Jawani Diwani': 2 occorrenze
# 'Penelope': 2 occorrenze
# 'Priya': 2 occorrenze
# 'Bhopal: A Prayer for Rain': 2 occorrenze
# 'Zanjeer': 2 occorrenze
# 'Frontier Marshal': 2 occorrenze
# 'Saudagar': 2 occorrenze
# 'Taxi': 2 occorrenze
# 'Loafer': 2 occorrenze
# 'Parthiban Kanavu': 2 occorrenze
# 'Mishima: A Life in Four Chapters': 2 occorrenze
# 'Kumara Raja': 2 occorrenze
# 'Babes in Toyland': 2 occorrenze
# 'Deewaar': 2 occorrenze
# 'Blood Brothers': 2 occorrenze
# 'Kaadu': 2 occorrenze
# 'Blue Steel': 2 occorrenze
# 'Bolero': 2 occorrenze
# 'Arya': 2 occorrenze
# 'Life of Pi': 2 occorrenze
# 'Brooklyn': 2 occorrenze
# 'The Razor's Edge': 2 occorrenze
# 'The Gigolo': 2 occorrenze
# 'Nobody Knows': 2 occorrenze
# 'The Postman Always Rings Twice': 2 occorrenze
# 'Chained': 2 occorrenze
# 'Humshakal': 2 occorrenze
# 'Bombay Mail': 2 occorrenze
# 'The Lemon Drop Kid': 2 occorrenze
# 'Little Men': 2 occorrenze
# 'Frankie and Johnny': 2 occorrenze
# 'Little Miss Marker': 2 occorrenze
# 'It's a Wonderful Life': 2 occorrenze
# 'It's Great to Be Young': 2 occorrenze
# 'Eagle's Claw': 2 occorrenze
# 'Sanjog': 2 occorrenze
# 'Kachche Dhaage': 2 occorrenze
# 'Original Sin': 2 occorrenze
# 'Maniac': 2 occorrenze
# 'Armed Response': 2 occorrenze
# 'Midnight': 2 occorrenze
# 'Iron Monkey': 2 occorrenze
# 'Behind Enemy Lines': 2 occorrenze
# 'Ramanujan': 2 occorrenze
# 'Big Trouble': 2 occorrenze
# 'White Lightning': 2 occorrenze
# 'A Man Could Get Killed': 2 occorrenze
# 'Lover Come Back': 2 occorrenze
# 'Anveshane': 2 occorrenze
# 'Bhagyada Lakshmi Baramma': 2 occorrenze
# 'Dharma': 2 occorrenze
# 'Imitation of Life': 2 occorrenze
# 'Bobby': 2 occorrenze
# 'Banarasi Babu': 2 occorrenze
# 'Anjada Gandu': 2 occorrenze
# 'The Killers': 2 occorrenze
# 'Anamika': 2 occorrenze
# 'Achanak': 2 occorrenze
# 'Dark Truth, AA Dark Truth': 2 occorrenze
# 'The Key': 2 occorrenze
# 'The Mirror': 2 occorrenze
# 'Grand Prix': 2 occorrenze
# 'Vice Squad': 2 occorrenze
# 'Jealousy': 2 occorrenze
# 'Return of the Fly': 2 occorrenze
# 'Swiss Family Robinson': 2 occorrenze
# 'Breaking News': 2 occorrenze
# 'Method': 2 occorrenze
# 'Flesh and the Spur': 2 occorrenze
# 'They Drive by Night': 2 occorrenze
# 'The Return of the Vampire': 2 occorrenze
# 'Lajja': 2 occorrenze
# 'The Mangler': 2 occorrenze
# 'Only You': 2 occorrenze
# 'Ghar Sansar': 2 occorrenze
# 'Untamed': 2 occorrenze
# 'Up in the Air': 2 occorrenze
# 'The Old Man and the Sea': 2 occorrenze
# 'The Phantom': 2 occorrenze
# 'The Wild': 2 occorrenze
# 'The Wicker Man': 2 occorrenze
# 'The Quiet American': 2 occorrenze
# 'Idiot': 2 occorrenze
# 'New Moon': 2 occorrenze
# 'The Condemned': 2 occorrenze
# 'Godzilla: Final Wars': 2 occorrenze
# 'Skin Deep': 2 occorrenze
# 'Teacher's Pet': 2 occorrenze
# 'Pinocchio': 2 occorrenze
# 'RoboCop 3': 2 occorrenze
# 'The Ladykillers': 2 occorrenze
# 'Red Rock West': 2 occorrenze
# '100% Love': 2 occorrenze
# 'Ten Little Indians': 2 occorrenze
# 'Romeo': 2 occorrenze
# 'Believe': 2 occorrenze
# 'Yasmin': 2 occorrenze
# 'She Couldn't Say No': 2 occorrenze
# 'Twister': 2 occorrenze
# 'Society': 2 occorrenze
# 'Jubilee': 2 occorrenze
# 'Daughter of Darkness': 2 occorrenze
# 'Spectre': 2 occorrenze
# 'How to Make a Monster': 2 occorrenze
# 'Death Machine': 2 occorrenze
# 'Bollywood Queen': 2 occorrenze
# 'Shall We Dance?': 2 occorrenze
# 'School for Scoundrels': 2 occorrenze
# 'Creep': 2 occorrenze
# 'Zenda': 2 occorrenze
# 'Collector': 2 occorrenze
# 'Prem Rog': 2 occorrenze
# 'The Intimate Stranger': 2 occorrenze
# 'Invasion of the Body Snatchers': 2 occorrenze
# 'Chala Bagundi': 2 occorrenze
# 'The Return': 2 occorrenze
# 'Relative Strangers': 2 occorrenze
# 'Hot Stuff': 2 occorrenze
# 'Avalon': 2 occorrenze
# 'Tommy': 2 occorrenze
# 'Young People': 2 occorrenze
# 'The Matchmaker': 2 occorrenze
# 'Glory': 2 occorrenze
# 'Machete': 2 occorrenze
# 'Bride of Re-Animator': 2 occorrenze
# 'The Great Man': 2 occorrenze
# 'Golmaal': 2 occorrenze
# 'Partner': 2 occorrenze
# 'The Phantom of the Opera': 2 occorrenze
# 'Stormbreaker': 2 occorrenze
# 'Barnacle Bill': 2 occorrenze
# 'Bedtime Story': 2 occorrenze
# 'Mahakaal': 2 occorrenze
# 'Doubles': 2 occorrenze
# 'In Love and War': 2 occorrenze
# 'Brindavanam': 2 occorrenze
# 'Top of the World': 2 occorrenze
# 'Dad's Army': 2 occorrenze
# 'SMS': 2 occorrenze
# 'Alfie': 2 occorrenze
# 'Friends': 2 occorrenze
# 'Buddha': 2 occorrenze
# 'House on Haunted Hill': 2 occorrenze
# 'Bachchan': 2 occorrenze
# 'The Punisher': 2 occorrenze
# 'The Hangman': 2 occorrenze
# 'Game': 2 occorrenze
# 'Busy Buddies': 2 occorrenze
# 'Jalsa': 2 occorrenze
# 'Baari Tar Bangla': 2 occorrenze
# 'Alive': 2 occorrenze
# 'Baahubali: The Beginning': 2 occorrenze
# 'Airborne': 2 occorrenze
# 'We're No Angels': 2 occorrenze
# 'Follow the Boys': 2 occorrenze
# 'The Go-Between': 2 occorrenze
# 'Karma': 2 occorrenze
# 'Redline': 2 occorrenze
# 'Loot': 2 occorrenze
# 'Farewell, My Lovely': 2 occorrenze
# 'Pride': 2 occorrenze
# 'Premonition': 2 occorrenze
# 'Top Gun': 2 occorrenze
# 'Black Friday': 2 occorrenze
# 'Dangerous Game': 2 occorrenze
# 'Roudram': 2 occorrenze
# 'Cannibal! The Musical': 2 occorrenze
# 'Currency': 2 occorrenze
# 'Flesh Gordon Meets the Cosmic Cheerleaders': 2 occorrenze
# 'Wonderland': 2 occorrenze
# 'To Catch a Thief': 2 occorrenze
# 'Bitter Sweet': 2 occorrenze
# '28': 2 occorrenze
# '20': 2 occorrenze
# 'The Invisible Woman': 2 occorrenze
# '18': 2 occorrenze
# 'Ben-Hur': 2 occorrenze
# 'Pulp': 2 occorrenze
# 'Behemoth, the Sea Monster': 2 occorrenze
# 'Beyond a Reasonable Doubt': 2 occorrenze
# 'Bluebeard': 2 occorrenze
# 'Trespass': 2 occorrenze
# 'Out of the Dark': 2 occorrenze
# 'Violent Cop': 2 occorrenze
# 'Tom and Jerry: The Movie': 2 occorrenze
# 'Crash': 2 occorrenze
# 'Assassin': 2 occorrenze
# 'Thumbelina': 2 occorrenze
# 'The Boss': 2 occorrenze
# 'Nowhere to Run': 2 occorrenze
# 'Khiladi': 2 occorrenze
# 'Before the Rains': 2 occorrenze
# 'Leviathan': 2 occorrenze
# 'Rangbaaz': 2 occorrenze
# 'Black Arrow': 2 occorrenze
# 'Anastasia': 2 occorrenze
# 'Puli': 2 occorrenze
# 'Attack': 2 occorrenze
# '19': 2 occorrenze
# 'High School': 2 occorrenze
# 'Three': 2 occorrenze
# 'Universal Soldier': 2 occorrenze
# 'Alaska': 2 occorrenze
# '27': 2 occorrenze
# 'The Adventures of Mark Twain': 2 occorrenze
# '30': 2 occorrenze
# '13': 2 occorrenze
# 'Atlantic City': 2 occorrenze
# 'Iddaru Mitrulu': 2 occorrenze
# 'Muscle Up a Little Closer': 2 occorrenze
# 'Jebu Donga': 2 occorrenze
# 'Lucia': 2 occorrenze
# 'The Wild Party': 2 occorrenze
# 'Born to Sing': 2 occorrenze
# 'Velugu Needalu': 2 occorrenze
# 'Yuvaraju': 2 occorrenze
# 'Ganesh': 2 occorrenze
# 'Cairo': 2 occorrenze
# '3:10 to Yuma': 2 occorrenze
# 'The Return of the Musketeers': 2 occorrenze
# 'Scandal': 2 occorrenze
# 'Cat People': 2 occorrenze
# '12 Angry Men': 2 occorrenze
# 'Into the Blue': 2 occorrenze
# 'The Island': 2 occorrenze
# 'This Time for Keeps': 2 occorrenze
# 'Above Suspicion': 2 occorrenze
# 'Aha Naa Pellanta': 2 occorrenze
# 'Till There Was You': 2 occorrenze
# 'Fantastic Four': 2 occorrenze
# 'Virginia': 2 occorrenze
# 'Total Recall': 2 occorrenze
# 'Lens': 2 occorrenze
# 'Srinivasa Kalyanam': 2 occorrenze
# 'The Witches': 2 occorrenze
# 'Paisa Paisa': 2 occorrenze
# 'Where the Heart Is': 2 occorrenze
# 'Memories': 2 occorrenze
# 'The Adventures of Smilin' Jack': 2 occorrenze
# 'Who Done It?': 2 occorrenze
# 'White Cargo': 2 occorrenze
# 'Click': 2 occorrenze
# 'Nightfall': 2 occorrenze
# 'Happy Wedding': 2 occorrenze
# 'Jungle Book': 2 occorrenze
# 'Devudu Chesina Manushulu': 2 occorrenze
# 'The Girl Most Likely': 2 occorrenze
# 'Premam': 2 occorrenze
# 'Mosagallaku Mosagadu': 2 occorrenze
# 'China Gate': 2 occorrenze
# 'Stay': 2 occorrenze
# 'Fire Down Below': 2 occorrenze
# 'Bandipotu': 2 occorrenze
# 'Varsham': 2 occorrenze
# 'A Night to Remember': 2 occorrenze
# 'Sudigundaalu': 2 occorrenze
# 'Nothing Personal': 2 occorrenze
# 'Katha Nayakudu': 2 occorrenze
# 'Proof': 2 occorrenze
# 'Manchi Kutumbam': 2 occorrenze
# 'The Delinquents': 2 occorrenze
# 'The Englishman Who Went Up a Hill But Came Down a Mountain': 2 occorrenze
# 'Punnami Naagu': 2 occorrenze
# 'Star Spangled Rhythm': 2 occorrenze
# 'Point Break': 2 occorrenze
# 'Interlude': 2 occorrenze
# 'Sati Savitri': 2 occorrenze
# 'Maro Charitra': 2 occorrenze
# 'Ramudu Bheemudu': 2 occorrenze
# 'Hit and Run': 2 occorrenze
# 'Bhaji on the Beach': 2 occorrenze
# 'Adavi Ramudu': 2 occorrenze
# 'Soggadu': 2 occorrenze
# 'Vegam': 2 occorrenze
# 'Uyyala Jampala': 2 occorrenze
# 'Avatharam': 2 occorrenze
# 'Just like a Woman': 2 occorrenze
# 'Prelude to War': 2 occorrenze
# 'Manchivadu': 2 occorrenze
# 'Yamagola': 2 occorrenze
# 'The Hard Way': 2 occorrenze
# 'Crash Landing': 2 occorrenze
# 'Palnati Yudham': 2 occorrenze
# 'Ratnamala': 2 occorrenze
# 'Jeevitham': 2 occorrenze
# 'Gladiator': 2 occorrenze
# 'Johnny Eager': 2 occorrenze
# 'Rakta Bandhan': 2 occorrenze
# 'Janaki Ramudu': 2 occorrenze
# 'Forever Young': 2 occorrenze
# 'The Blob': 2 occorrenze
# 'Bad Blood': 2 occorrenze
# 'Chokher Bali': 2 occorrenze
# 'Letters from Iwo Jima': 2 occorrenze
# 'Pelli Chesi Choodu': 2 occorrenze
# 'Enigma': 2 occorrenze
# 'Lord of the Flies': 2 occorrenze
# 'The Long Weekend': 2 occorrenze
# 'The Feminine Touch': 2 occorrenze
# 'Fiesta': 2 occorrenze
# 'Flatliners': 2 occorrenze
# 'In This World': 2 occorrenze
# 'Pulse': 2 occorrenze
# 'The Gang's All Here': 2 occorrenze
# 'Khalnayak': 2 occorrenze
# 'Holy Matrimony': 2 occorrenze
# 'Lavender': 2 occorrenze
# 'The Guardian': 2 occorrenze
# 'North Sea Hijack': 2 occorrenze
# 'Seeta Rama Jananam': 2 occorrenze
# 'Krishna Prema': 2 occorrenze
# 'The King and I': 2 occorrenze
# 'A Kiss Before Dying': 2 occorrenze
# 'Ram Lakshman': 2 occorrenze
# 'Heaven Can Wait': 2 occorrenze
# 'Daisy': 2 occorrenze
# 'Destroyer': 2 occorrenze
# 'Cal': 2 occorrenze
# 'Killer': 2 occorrenze
# 'The Rainmaker': 2 occorrenze
# 'Missamma': 2 occorrenze
# 'Santosham': 2 occorrenze
# 'This Angry Age': 2 occorrenze
# 'The Constant Nymph': 2 occorrenze
# 'Rakshana': 2 occorrenze
# 'Chiranjeevulu': 2 occorrenze
# 'The Strange World of Planet X': 2 occorrenze
# 'Aalu Magalu': 2 occorrenze
# 'Anuradha': 2 occorrenze
# 'Water': 2 occorrenze
# 'Yamudiki Mogudu': 2 occorrenze
# 'Shipwrecked': 2 occorrenze
# 'Dark Water': 2 occorrenze
# 'Blown Away': 2 occorrenze
# 'Madhouse': 2 occorrenze
# 'Forever and a Day': 2 occorrenze
# 'Another Time, Another Place': 2 occorrenze
# 'Prem Shakti': 2 occorrenze
# 'Million Dollar Baby': 2 occorrenze
# 'Young and Dangerous': 2 occorrenze
# 'Men of Respect': 2 occorrenze
# 'Mr. & Mrs. Smith': 2 occorrenze
# 'Hatey Bazarey': 2 occorrenze
# 'Sundarakanda': 2 occorrenze
# 'Bhalobasa Bhalobasa': 2 occorrenze
# 'Up in Smoke': 2 occorrenze
# 'Lakshyam': 2 occorrenze
# 'Pratidwandi': 2 occorrenze
# 'Happy Feet': 2 occorrenze
# 'The Wind in the Willows': 2 occorrenze
# 'Paris Calling': 2 occorrenze
# 'Sangham': 2 occorrenze
# 'Nirnayam': 2 occorrenze
# 'Undercover Blues': 2 occorrenze
# 'Inspector': 2 occorrenze
# 'Hatim Tai': 2 occorrenze
# 'Devta': 2 occorrenze
# 'Funtoosh': 2 occorrenze
# 'Bhai-Bhai': 2 occorrenze
# 'Raj Hath': 2 occorrenze
# 'The Shaggy Dog': 2 occorrenze
# 'Basant Bahar': 2 occorrenze
# 'Dangerous Liaisons': 2 occorrenze
# 'Ek Hi Raasta': 2 occorrenze
# 'Too Late Blues': 2 occorrenze
# 'The High Bright Sun': 2 occorrenze
# 'The Uninvited': 2 occorrenze
# 'Foxfire': 2 occorrenze
# 'Something Wild': 2 occorrenze
# 'New Delhi': 2 occorrenze
# 'Varaphalam': 2 occorrenze
# 'Ponthan Mada': 2 occorrenze
# 'The Beast': 2 occorrenze
# 'Pyaasa': 2 occorrenze
# '3': 2 occorrenze
# 'The Informers': 2 occorrenze
# 'Mother India': 2 occorrenze
# 'Kathputli': 2 occorrenze
# 'City Girl': 2 occorrenze
# 'The Servant': 2 occorrenze
# 'The End of the Affair': 2 occorrenze
# 'Cape Fear': 2 occorrenze
# 'Bulletproof': 2 occorrenze
# 'C.H.U.D. II: Bud the C.H.U.D.': 2 occorrenze
# 'Aasha': 2 occorrenze
# 'Santhanagopalam': 2 occorrenze
# 'Sailaab': 2 occorrenze
# 'The Scarlet Blade': 2 occorrenze
# 'Nastik': 2 occorrenze
# 'My Lucky Star': 2 occorrenze
# 'Munna': 2 occorrenze
# 'Grave of the Fireflies': 2 occorrenze
# 'Chakradhari': 2 occorrenze
# 'The Flying Machine': 2 occorrenze
# 'Penitentiary': 2 occorrenze
# 'Hysteria': 2 occorrenze
# 'The Gamma People': 2 occorrenze
# 'Aar Paar': 2 occorrenze
# 'Kannaki': 2 occorrenze
# 'Heathers': 2 occorrenze
# 'Nagaravadhu': 2 occorrenze
# 'Asura': 2 occorrenze
# 'Paradesi': 2 occorrenze
# 'Shahenshah': 2 occorrenze
# 'Patita': 2 occorrenze
# 'Darkness Falls': 2 occorrenze
# 'Darling Darling': 2 occorrenze
# 'Island in the Sky': 2 occorrenze
# 'The Tiger Woman': 2 occorrenze
# 'Kattu Vannu Vilichappol': 2 occorrenze
# 'The Roman Spring of Mrs. Stone': 2 occorrenze
# 'The Three Caballeros': 2 occorrenze
# 'Jagathalaprathapan': 2 occorrenze
# 'Bride Wars': 2 occorrenze
# 'Devakanya': 2 occorrenze
# 'Life Is Beautiful': 2 occorrenze
# 'Haridas': 2 occorrenze
# 'Azaad': 2 occorrenze
# 'Marie Antoinette': 2 occorrenze
# 'The Pit and the Pendulum': 2 occorrenze
# 'Rakshasa Rajavu': 2 occorrenze
# 'The Parent Trap': 2 occorrenze
# 'Samrat': 2 occorrenze
# 'The Box': 2 occorrenze
# 'Heidi': 2 occorrenze
# 'Mr. India': 2 occorrenze
# 'Hum Dono': 2 occorrenze
# 'The Hurricane': 2 occorrenze
# 'Samsaram': 2 occorrenze
# 'What Goes Up': 2 occorrenze
# 'Parijatham': 2 occorrenze
# 'Kid Galahad': 2 occorrenze
# 'Swaham': 2 occorrenze
# 'Dillinger': 2 occorrenze
# 'Dick Tracy': 2 occorrenze
# 'Detour': 2 occorrenze
# 'Mannequin': 2 occorrenze
# 'Sweet Bird of Youth': 2 occorrenze
# 'Tekken': 2 occorrenze
# 'Marry the Girl': 2 occorrenze
# 'The Stepfather': 2 occorrenze
# 'The Trial': 2 occorrenze
# 'Red Beard': 2 occorrenze
# 'The Devil's Playground': 2 occorrenze
# 'Faithfully Yours': 2 occorrenze
# 'The Comedy of Terrors': 2 occorrenze
# 'Easy Living': 2 occorrenze
# 'Escape by Night': 2 occorrenze
# 'Appu': 2 occorrenze
# 'Prison': 2 occorrenze
# 'Nazrana': 2 occorrenze
# 'A Family Affair': 2 occorrenze
# 'China Town': 2 occorrenze
# 'Bees Saal Baad': 2 occorrenze
# 'Police Story 2': 2 occorrenze
# 'Shola Aur Shabnam': 2 occorrenze
# 'RoboCop': 2 occorrenze
# 'Roop Ki Rani Choron Ka Raja': 2 occorrenze
# 'The Running Man': 2 occorrenze
# 'Project X': 2 occorrenze
# 'On the Beat': 2 occorrenze
# 'Lolita': 2 occorrenze
# 'Jack the Giant Killer': 2 occorrenze
# 'Bewitched': 2 occorrenze
# 'The Messenger': 2 occorrenze
# 'The Intruder': 2 occorrenze
# 'Parvarish': 2 occorrenze
# 'Madhumati': 2 occorrenze
# 'Sodom and Gomorrah': 2 occorrenze
# 'Action Jackson': 2 occorrenze
# 'Do Phool': 2 occorrenze
# 'Trishna': 2 occorrenze
# 'Amar Deep': 2 occorrenze
# 'And Then There Were None': 2 occorrenze
# 'A Dangerous Method': 2 occorrenze
# 'Vidheyan': 2 occorrenze
# 'Sharada': 2 occorrenze
# 'The Very Edge': 2 occorrenze
# 'Late Autumn': 2 occorrenze
# 'Kohinoor': 2 occorrenze
# 'Kavacham': 2 occorrenze
# 'The Killer': 2 occorrenze
# 'Superman IV: The Quest for Peace': 2 occorrenze
# 'The Outcasts of Poker Flat': 2 occorrenze
# 'Third Contact': 2 occorrenze
# 'At Gunpoint': 2 occorrenze
# 'Wanted: Dead or Alive': 2 occorrenze
# 'College Girl': 2 occorrenze
# 'Chhalia': 2 occorrenze
# 'Circumstantial Evidence': 2 occorrenze
# 'No Exit': 2 occorrenze
# 'Vietnam Colony': 2 occorrenze
# 'The Manchurian Candidate': 2 occorrenze
# 'Apoorva Sagodharargal': 2 occorrenze
# 'A Star Is Born': 2 occorrenze
# 'Come Out Fighting': 2 occorrenze
# 'Monster': 2 occorrenze
# 'Never Say Die': 2 occorrenze
# 'Watchers': 2 occorrenze
# 'Aasai': 2 occorrenze
# 'Of Mice and Men': 2 occorrenze
# 'Gokulam': 2 occorrenze
# 'Baba Kalyani': 2 occorrenze
# 'National Security': 2 occorrenze
# 'The Indian Fighter': 2 occorrenze
# 'The Oregon Trail': 2 occorrenze
# 'Ekantham': 2 occorrenze
# 'Jailor': 2 occorrenze
# 'Lanka': 2 occorrenze
# 'Bronco Bullfrog': 2 occorrenze
# 'Bhabhi': 2 occorrenze
# 'All Dogs Go to Heaven': 2 occorrenze
# 'Rio': 2 occorrenze
# 'Witchcraft': 2 occorrenze
# 'The Kid from Texas': 2 occorrenze
# 'King of the Underworld': 2 occorrenze
# 'Pooja': 2 occorrenze
# 'The Eye': 2 occorrenze
# 'Holi': 2 occorrenze
# 'Heartless': 2 occorrenze
# 'The Light That Failed': 2 occorrenze
# 'Chingari': 2 occorrenze
# 'Vice Versa': 2 occorrenze
# 'Bharosa': 2 occorrenze
# 'The Man in the Iron Mask': 2 occorrenze
# 'The Missing': 2 occorrenze
# 'Performance': 2 occorrenze
# 'The Deal': 2 occorrenze
# 'Thokar': 2 occorrenze
# 'Pukar': 2 occorrenze
# 'Ladies Only': 2 occorrenze
# 'Made for Each Other': 2 occorrenze
# 'The Firm': 2 occorrenze
# 'Cousins': 2 occorrenze
# 'Joru': 2 occorrenze
# 'Stardust': 2 occorrenze
# 'Fearless': 2 occorrenze
# 'Okka Kshanam': 2 occorrenze
# 'Nagaram': 2 occorrenze
# 'The Women': 2 occorrenze
# 'Always': 2 occorrenze
# 'Gaslight': 2 occorrenze
# 'Tarzan, the Ape Man': 2 occorrenze
# 'Tarzan's Greatest Adventure': 2 occorrenze
# 'Day One': 2 occorrenze
# 'Soldier of Fortune': 2 occorrenze
# 'Some Like It Hot': 2 occorrenze
# 'Sleeping Beauty': 2 occorrenze
# 'Always a Bride': 2 occorrenze
# 'Sleuth': 2 occorrenze
# 'Second Fiddle': 2 occorrenze
# 'Savitri': 2 occorrenze
# 'Mukti': 2 occorrenze
# 'Ravanan': 2 occorrenze
# 'Leo the Last': 2 occorrenze
# 'Stagecoach': 2 occorrenze
# 'Black Rain': 2 occorrenze
# 'The Alamo': 2 occorrenze
# 'Tower of London': 2 occorrenze
# 'War': 2 occorrenze
# 'Bridesmaids': 2 occorrenze
# 'Happily Ever After': 2 occorrenze
# 'The Reckoning': 2 occorrenze
# 'The Wasp Woman': 2 occorrenze
# 'Sweeney Todd: The Demon Barber of Fleet Street': 2 occorrenze
# 'Warlock': 2 occorrenze
# 'Sunshine': 2 occorrenze
# '9 KK Road': 2 occorrenze
# 'Sansar': 2 occorrenze
# 'Shutter': 2 occorrenze
# 'Videsi Nair Swadesi Nair': 2 occorrenze
# 'Barricade': 2 occorrenze
# 'Oh, What a Night': 2 occorrenze
# 'Chakram': 2 occorrenze
# 'Honey': 2 occorrenze
# 'Rambo': 2 occorrenze
# 'Jackboots on Whitehall': 2 occorrenze
# 'Mahal': 2 occorrenze
# 'Angel Baby': 2 occorrenze
# 'Coriolanus': 2 occorrenze
# 'Bazaar': 2 occorrenze
# 'Barsaat': 2 occorrenze
# 'Ellis R. Dungan': 2 occorrenze
# 'Parinamam': 2 occorrenze
# 'Attack on the Iron Coast': 2 occorrenze
# 'Hope Springs': 2 occorrenze
# 'Sundara Purushan': 2 occorrenze
# 'Three Blind Mice': 2 occorrenze
# 'Dheena': 2 occorrenze
# 'Too Hot to Handle': 2 occorrenze
# 'Kenny': 2 occorrenze
# 'Rough': 2 occorrenze
# 'Shame': 2 occorrenze
# 'Maa': 2 occorrenze
# 'Sazaa': 2 occorrenze
# 'Kuberan': 2 occorrenze
# 'You and Me': 2 occorrenze
# 'Deewana': 2 occorrenze
# 'Romeo Is Bleeding': 2 occorrenze
# 'Outcast': 2 occorrenze
# 'Anhonee': 2 occorrenze
# 'Almost a Gentleman': 2 occorrenze
# 'Masquerade': 2 occorrenze
# 'The Strangers': 2 occorrenze
# 'Sathyam': 2 occorrenze
# 'Jwar Bhata': 2 occorrenze
# 'Vajram': 2 occorrenze
# 'Gulliver's Travels': 2 occorrenze
# 'Ram Rajya': 2 occorrenze
# 'Matinee': 2 occorrenze
# 'Psycho': 2 occorrenze
# 'Hell's Kitchen': 2 occorrenze
# 'Apna Desh': 2 occorrenze
# 'The Hound of the Baskervilles': 2 occorrenze
# 'Cuckoo': 2 occorrenze
# 'Boy': 2 occorrenze
# 'Armaan': 2 occorrenze
# 'Sikandar': 2 occorrenze
# 'Black Sun: The Nanking Massacre': 2 occorrenze
# 'The Magnificent Seven': 2 occorrenze
# 'Anjaan': 2 occorrenze
# 'Kunwara Baap': 2 occorrenze
# 'Berserk!': 2 occorrenze
# 'Basement': 2 occorrenze
# 'Ghar Ki Izzat': 2 occorrenze
# 'Much Ado About Nothing': 2 occorrenze
# 'Anokhi Ada': 2 occorrenze
# 'The Italian Job': 2 occorrenze
# 'Sindoor': 2 occorrenze
# 'The Time Machine': 2 occorrenze
# 'Shararat': 2 occorrenze
# 'Chithariyavar': 2 occorrenze
# 'Shadow': 2 occorrenze
# 'Sajan': 2 occorrenze
# 'The Vampires of Bloody Island': 2 occorrenze
# 'Just Married': 2 occorrenze
# 'Dard': 2 occorrenze
# 'Valmiki': 2 occorrenze
# 'Summer of the Seventeenth Doll': 2 occorrenze
# 'First Love': 2 occorrenze
# 'Puss in Boots': 2 occorrenze
# 'Sathya': 2 occorrenze
# 'Pasi': 2 occorrenze
# 'Hail, Caesar!': 2 occorrenze
# 'New Year's Eve': 2 occorrenze
# 'Botany Bay': 2 occorrenze
# 'Bloodhounds of Broadway': 2 occorrenze
# 'Mexicali Rose': 2 occorrenze
# 'The Man I Love': 2 occorrenze
# 'Ghajini': 2 occorrenze
# 'Buddy': 2 occorrenze
# 'The Witch': 2 occorrenze
# 'The Letter': 2 occorrenze
# 'The End of the Road': 2 occorrenze
# 'The Beguiled': 2 occorrenze
# 'East Meets West': 2 occorrenze
# 'The Kiss': 2 occorrenze
# 'The Fan': 2 occorrenze
# 'Honky Tonk': 2 occorrenze
# 'They Live by Night': 2 occorrenze
# 'Eyewitness': 2 occorrenze
# 'Happy Days': 2 occorrenze
# 'Endless Love': 2 occorrenze
# 'Johnny': 2 occorrenze
# 'Runway': 2 occorrenze
# 'Badges of Fury': 2 occorrenze
# 'Hello': 2 occorrenze
# 'Kabrastan': 2 occorrenze
# 'Unfaithfully Yours': 2 occorrenze
# 'The Last of Mrs. Cheyney': 2 occorrenze
# 'Dum': 2 occorrenze
# 'Trent's Last Case': 2 occorrenze
# 'Hard Eight': 2 occorrenze
# 'Flawless': 2 occorrenze
# 'The Last Chase': 2 occorrenze
# 'The Thirteenth Chair': 2 occorrenze
# 'Broken Arrow': 2 occorrenze
# 'Black Mass': 2 occorrenze
# 'Everest': 2 occorrenze
# 'The Martian': 2 occorrenze
# 'Laughing Gas': 2 occorrenze
# 'Out of Inferno': 2 occorrenze
# 'Platform': 2 occorrenze
# 'So Dear to My Heart': 2 occorrenze
# 'Superman': 2 occorrenze
# 'Side Street': 2 occorrenze
# 'Snowden': 2 occorrenze
# 'Jodi': 2 occorrenze
# 'Election': 2 occorrenze
# 'Willard': 2 occorrenze
# 'Born Yesterday': 2 occorrenze
# 'Ninaithale Inikkum': 2 occorrenze
# 'Hungama': 2 occorrenze
# 'Rio Rita': 2 occorrenze
# 'School Bus': 2 occorrenze
# 'Ip Man 3': 2 occorrenze
# 'Juggernaut': 2 occorrenze
# 'The One and Only': 2 occorrenze
# 'Ghost Story': 2 occorrenze
# 'The Enforcer': 2 occorrenze
# 'En Vazhi Thani Vazhi': 2 occorrenze
# 'The Last House on the Left': 2 occorrenze
# 'West of Zanzibar': 2 occorrenze
# 'Agnee': 2 occorrenze
# 'The Viking': 2 occorrenze
# 'The BFG': 2 occorrenze
# 'The Accused': 2 occorrenze
# 'Ami Shudhu Cheyechi Tomay': 2 occorrenze
# 'Submarine': 2 occorrenze
# '10': 2 occorrenze
# 'All Night Long': 2 occorrenze
# 'Kazhugu': 2 occorrenze
# 'Among Those Present': 2 occorrenze
# 'Mouth to Mouth': 2 occorrenze
# 'Endless Night': 2 occorrenze
# 'Sugar Hill': 2 occorrenze
# 'Lewis and Clark and George': 2 occorrenze
# 'The Mechanic': 2 occorrenze
# 'The Showdown': 2 occorrenze
# 'The 39 Steps': 2 occorrenze
# 'Brahma': 2 occorrenze
# 'The Amityville Horror': 2 occorrenze
# 'All the King's Men': 2 occorrenze
# 'Jade Goddess of Mercy': 2 occorrenze
# 'Palaivana Solai': 2 occorrenze
# 'The Tell-Tale Heart': 2 occorrenze
# 'Florence Foster Jenkins': 2 occorrenze
# 'The Watcher in the Woods': 2 occorrenze
# 'Big Brother': 2 occorrenze
# 'The Man': 2 occorrenze
# 'The Miracle Man': 2 occorrenze
# 'The Wrestler': 2 occorrenze
# 'The Desert Song': 2 occorrenze
# 'The Vicious Circle': 2 occorrenze
# 'A Dangerous Woman': 2 occorrenze
# 'Dangerous Curves': 2 occorrenze
# 'Clash of the Titans': 2 occorrenze
# 'Dance Hall': 2 occorrenze
# 'The Getaway': 2 occorrenze
# 'Polladhavan': 2 occorrenze
# 'Circle of Power': 2 occorrenze
# 'Khushi': 2 occorrenze
# 'Backfire': 2 occorrenze
# 'Drug War': 2 occorrenze
# 'Guru Sishyan': 2 occorrenze
# 'The Avengers': 2 occorrenze
# 'Saazish': 2 occorrenze
# 'Broadway': 2 occorrenze
# 'Big Business': 2 occorrenze
# 'Me Before You': 2 occorrenze
# 'The Aviator': 2 occorrenze
# 'Alibi': 2 occorrenze
# 'Journey to the West: Conquering the Demons': 2 occorrenze
# 'Idhu Namma Aalu': 2 occorrenze
# 'Angel Face': 2 occorrenze
# 'Best Laid Plans': 2 occorrenze
# 'Beowulf': 2 occorrenze
# 'Arthur': 2 occorrenze
# 'While the City Sleeps': 2 occorrenze
# 'Whiplash': 2 occorrenze
# 'Bhishma': 2 occorrenze
# 'Into the Woods': 2 occorrenze
# 'Moby Dick': 2 occorrenze
# 'Seenu': 2 occorrenze
# 'Fright': 2 occorrenze
# 'Sarfarosh': 2 occorrenze
# 'Butterfly': 2 occorrenze
# 'U Turn': 2 occorrenze
# 'Invasion U.S.A.': 2 occorrenze
# 'Paddington': 2 occorrenze
# 'The I Don't Care Girl': 2 occorrenze
# 'The Edge': 2 occorrenze
# 'Mortdecai': 2 occorrenze
# 'The Life of the Party': 2 occorrenze
# 'The Valiant': 2 occorrenze
# 'Amma': 2 occorrenze
# 'The Hunting Party': 2 occorrenze
# 'Jupiter Ascending': 2 occorrenze
# 'Mickey': 2 occorrenze
# 'Seventh Son': 2 occorrenze
# 'Girlfriends': 2 occorrenze
# 'Nine-Tenths of the Law': 2 occorrenze
# 'Siva': 2 occorrenze
# 'Fifty Shades of Grey': 2 occorrenze
# 'Kingsman: The Secret Service': 2 occorrenze
# 'Hit the Deck': 2 occorrenze
# 'Dark City': 2 occorrenze
# 'But Always': 2 occorrenze
# 'Hide-Out': 2 occorrenze
# 'The House of Mirth': 2 occorrenze
# 'Anbe Aaruyire': 2 occorrenze
# 'The Big Night': 2 occorrenze
# 'Flash': 2 occorrenze
# 'Wild and Woolly': 2 occorrenze
# 'The Glass Menagerie': 2 occorrenze
# 'Son of a Gun': 2 occorrenze
# 'The Blue Bird': 2 occorrenze
# 'Badri': 2 occorrenze
# 'Lone Star': 2 occorrenze
# 'Posse': 2 occorrenze
# 'Coming Home': 2 occorrenze
# 'Interstellar': 2 occorrenze
# 'Limelight': 2 occorrenze
# 'Convoy': 2 occorrenze
# 'Monte Carlo': 2 occorrenze
# 'Raffles': 2 occorrenze
# 'The Ex': 2 occorrenze
# 'Tower of Terror': 2 occorrenze
# 'Dawn of the Dead': 2 occorrenze
# 'Outside the Law': 2 occorrenze
# 'Only the Brave': 2 occorrenze
# 'Just for You': 2 occorrenze
# 'Trial and Error': 2 occorrenze
# 'Exodus: Gods and Kings': 2 occorrenze
# 'Father of the Bride': 2 occorrenze
# 'The Last Supper': 2 occorrenze
# 'Night at the Museum: Secret of the Tomb': 2 occorrenze
# 'Murder Will Out': 2 occorrenze
# 'Conan the Barbarian': 2 occorrenze
# 'Maa Kasam': 2 occorrenze
# 'Pitfall': 2 occorrenze
# 'Rich and Famous': 2 occorrenze
# 'Cheaper by the Dozen': 2 occorrenze
# 'Child 44': 2 occorrenze
# 'Bright Lights': 2 occorrenze
# 'The Funeral': 2 occorrenze
# 'The Monkey King': 2 occorrenze
# 'Born Reckless': 2 occorrenze
# 'Red River': 2 occorrenze
# 'Blackbird': 2 occorrenze
# 'An Ideal Husband': 2 occorrenze
# 'See No Evil': 2 occorrenze
# 'The High Command': 2 occorrenze
# 'Held Up': 2 occorrenze
# 'The Vulture': 2 occorrenze
# 'Daddy Cool': 2 occorrenze
# 'When Marnie Was There': 2 occorrenze
# 'Broken Blossoms': 2 occorrenze
# 'Road House': 2 occorrenze
# 'Veera': 2 occorrenze
# 'Words and Music': 2 occorrenze
# 'Spy': 2 occorrenze
# 'Straw Dogs': 2 occorrenze
# 'Sadhurangam': 2 occorrenze
# 'Go': 2 occorrenze
# 'Police Story 2013': 2 occorrenze
# 'Max': 2 occorrenze
# 'The Virginian': 2 occorrenze
# 'Maidan-E-Jung': 2 occorrenze
# 'Shaft': 2 occorrenze
# 'Mahanadi': 2 occorrenze
# 'Halloween': 2 occorrenze
# 'Bliss': 2 occorrenze
# 'Tuck Everlasting': 2 occorrenze
# 'Life': 2 occorrenze
# 'The Naked City': 2 occorrenze
# 'Maps to the Stars': 2 occorrenze
# 'Radio': 2 occorrenze
# 'D.O.A.': 2 occorrenze
# 'The Gorilla': 2 occorrenze
# 'Rajadhi Raja': 2 occorrenze
# 'The Girl Said No': 2 occorrenze
# 'The Second Best Exotic Marigold Hotel': 2 occorrenze
# 'Vikram Bhatt': 2 occorrenze
# 'Conspiracy': 2 occorrenze
# 'The Furies': 2 occorrenze
# 'Free and Easy': 2 occorrenze
# 'Jeeva': 2 occorrenze
# 'Wrecked': 2 occorrenze
# 'Southern Comfort': 2 occorrenze
# 'The Gunman': 2 occorrenze
# 'Blue': 2 occorrenze
# 'The Fighter': 2 occorrenze
# 'Home': 2 occorrenze
# 'Serena': 2 occorrenze
# 'The Dawn Patrol': 2 occorrenze
# 'Magalir Mattum': 2 occorrenze
# 'Woman in Gold': 2 occorrenze
# 'Ex Machina': 2 occorrenze
# 'The Day the Earth Stood Still': 2 occorrenze
# 'Baby Driver': 2 occorrenze
# 'The House': 2 occorrenze
# 'She's the One': 2 occorrenze
# 'Paisa Vasool': 2 occorrenze
# 'The Lady Vanishes': 2 occorrenze
# 'Downhill': 2 occorrenze
# 'Samson and Delilah': 2 occorrenze
# 'Phantom of the Opera': 2 occorrenze
# 'The Prowler': 2 occorrenze
# 'Three to Go': 2 occorrenze
# 'The Merry Widow': 2 occorrenze
# 'The Man Who Found Himself': 2 occorrenze
# 'Bodyguards and Assassins': 2 occorrenze
# 'Animal Farm': 2 occorrenze
# 'Mr. Nobody': 2 occorrenze
# 'Blood and Sand': 2 occorrenze
# 'The Lost World': 2 occorrenze
# 'Crooked House': 2 occorrenze
# 'The Lady': 2 occorrenze
# 'A Kiss for Cinderella': 2 occorrenze
# 'Werewolf': 2 occorrenze
# 'The Dark Tower': 2 occorrenze
# 'Kidnap': 2 occorrenze
# 'Wind River': 2 occorrenze
# 'Ocean Flame': 2 occorrenze
# 'Go West': 2 occorrenze
# 'The Freshman': 2 occorrenze
# 'The Blue Peter': 2 occorrenze
# 'All the Money in the World': 2 occorrenze
# 'The Office Picnic': 2 occorrenze
# 'Rhubarb': 2 occorrenze
# 'The Boy Friend': 2 occorrenze
# '14 Blades': 2 occorrenze
# 'The Set-Up': 2 occorrenze
# 'Home of the Brave': 2 occorrenze
# 'The In-Laws': 2 occorrenze
# 'Ringmaster': 2 occorrenze
# 'Enakkul Oruvan': 2 occorrenze
# 'The Bells': 2 occorrenze
# 'The Secret Garden': 2 occorrenze
# 'Beau Geste': 2 occorrenze
# 'Gloria': 2 occorrenze
# 'The Bat': 2 occorrenze
# 'The Fog': 2 occorrenze
# 'The Rat': 2 occorrenze
# 'The Golden Voyage of Sinbad': 2 occorrenze
# 'Across the Pacific': 2 occorrenze
# 'Tracing Shadow': 2 occorrenze
# 'Friday the 13th': 2 occorrenze
# 'London': 2 occorrenze
# 'The Unholy Three': 2 occorrenze
# 'Tumbleweeds': 2 occorrenze
# '47 Meters Down': 2 occorrenze
# 'Naan Mahaan Alla': 2 occorrenze
# 'Mademoiselle from Armentieres': 2 occorrenze
# 'Nothing But Life': 2 occorrenze
# 'Gopala Gopala': 2 occorrenze
# 'Impact': 2 occorrenze
# 'The Winner': 2 occorrenze
# 'Drohi': 2 occorrenze
# 'Mandhira Punnagai': 2 occorrenze
# 'No Smoking': 2 occorrenze
# 'Darkest Hour': 2 occorrenze
# 'Shadows': 2 occorrenze
# 'Feet of Clay': 2 occorrenze
# 'The Family Secret': 2 occorrenze
# 'The Flying Scotsman': 2 occorrenze
# 'The Enchanted Cottage': 2 occorrenze
# 'Dante's Inferno': 2 occorrenze
# 'High Treason': 2 occorrenze
# 'Captain January': 2 occorrenze
# 'Mini': 2 occorrenze
# 'Slither': 2 occorrenze
# 'The Dark Angel': 2 occorrenze
# %%
# Creiamo un nuovo DataFrame senza titoli duplicati
# Manteniamo solo la prima occorrenza di ogni titolo

df_unico = df.drop_duplicates(subset=['Title'], keep='first').reset_index(drop=True)

print(f"Il nuovo DataFrame contiene {len(df_unico)} righe, tutte con titolo unico.")
# Out:
# Il nuovo DataFrame contiene 32432 righe, tutte con titolo unico.

# %%
# Troviamo i titoli duplicati
# value_counts() conta quante volte appare ogni titolo
conteggio_titoli = df_unico['Title'].value_counts()

# Filtriamo solo i titoli che appaiono più di una volta
titoli_duplicati = conteggio_titoli[conteggio_titoli > 1]

if len(titoli_duplicati) > 0:
    print(f"Trovati {len(titoli_duplicati)} titoli duplicati\n")
    print("Lista dei titoli duplicati e numero di occorrenze:")
    print("="*50)
    
    # Creiamo una lista ordinata dei titoli duplicati con il loro conteggio
    for titolo, conteggio in titoli_duplicati.items():
        print(f"'{titolo}': {conteggio} occorrenze")
    
    # Creiamo una lista dei soli titoli duplicati
    lista_titoli_duplicati = list(titoli_duplicati.index)
    
    print("\nLista dei titoli duplicati:")
    print("="*50)
    for i, titolo in enumerate(lista_titoli_duplicati, 1):
        print(f"{i}. {titolo}")
else:
    print("Non sono stati trovati titoli duplicati nel dataset")
# Out:
# Non sono stati trovati titoli duplicati nel dataset

# %%
df_unico.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32432 entries, 0 to 32431
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Release Year      32432 non-null  int64
#  1   Title             32432 non-null  object
#  2   Origin/Ethnicity  32432 non-null  object
#  3   Director          32432 non-null  object
#  4   Cast              31130 non-null  object
#  5   Genre             32432 non-null  object
#  6   Wiki Page         32432 non-null  object
#  7   Plot              32432 non-null  object
# dtypes: int64(1), object(7)
# memory usage: 2.0+ MB

# %% [markdown]
# ## Creazione Directory per indicizzazione
# Creiamo per ogni record del dataset un file testuale a seguito di un atraduzione dei campi 'Title' e 'Plot' in lingua italiana
# - Title = nome del file
# - Plot = contenuto del file

# %%
import os
import re
from tqdm import tqdm
from deep_translator import GoogleTranslator

# === CONFIGURAZIONE ===
csv_path = "a.csv"   # percorso del dataset originale
output_dir = "files"                # cartella dove salvare i file tradotti
title_col = "Title"
content_col = "Plot"
n_files = 5000  # numero di file da processare
# =======================

# Crea la cartella di output se non esiste
os.makedirs(output_dir, exist_ok=True)

# Carica il dataset
df = df_unico.head(n_files)

# Inizializza il traduttore
translator = GoogleTranslator(source='en', target='it')

# Contatore dei file creati con successo
success_count = 0

# Traduci e salva i file
for _, row in tqdm(df.iterrows(), total=len(df), desc="Traduzione e generazione file"):
    title = str(row[title_col]).strip()
    content = str(row[content_col]).strip()

    try:
        # Traduzione
        title_it = translator.translate(title)
        content_it = translator.translate(content)

        # Pulizia minima del titolo per il nome del file
        safe_title = re.sub(r'[\\/*?:"<>|]', '_', title_it)

        # Percorso del file
        file_path = os.path.join(output_dir, f"{safe_title}.txt")

        # Scrittura del contenuto solo se la traduzione è riuscita
        with open(file_path, "w", encoding="utf-8") as f:
            f.write(content_it)

        success_count += 1

    except Exception as e:
        continue  # passa al prossimo record senza salvare nulla

print(f"\n✅ Creati {success_count} file tradotti in italiano nella cartella '{output_dir}'")
